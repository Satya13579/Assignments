# %% [markdown]
# ### Step 1: Loading and Understanding the Data

# %%
#Import required Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from sklearn.metrics import r2_score

# %%
#Loading the Data
df = pd.read_csv('day.csv')

print(df.shape) 
df.head()
# Out:
# (730, 16)
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# checking for the null values in column data
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# get the info about columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
# renaming few columns for better understanding
df.rename(columns={'yr':'year','mnth':'month','hum':'humidity', 'cnt':'total_count'}, inplace=True)
df.head()
# Out:
#    instant      dteday  season  year  month  holiday  weekday  workingday  \
# 0        1  01-01-2018       1     0      1        0        1           1
# 1        2  02-01-2018       1     0      1        0        2           1
# 2        3  03-01-2018       1     0      1        0        3           1
# 3        4  04-01-2018       1     0      1        0        4           1
# 4        5  05-01-2018       1     0      1        0        5           1
#
#    weathersit       temp     atemp  humidity  windspeed  casual  registered  \
# 0           2  14.110847  18.18125   80.5833  10.749882     331         654
# 1           2  14.902598  17.68695   69.6087  16.652113     131         670
# 2           1   8.050924   9.47025   43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610   59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350   43.6957  12.522300      82        1518
#
#    total_count
# 0          985
# 1          801
# ...

# %%
# describing the columns of dataframe
df.describe()
# Out:
#           instant      season        year       month     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp    humidity   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
# dropping the unwanted columns
# instant has only index for the row, dteday has date which can be compensated by year and month column,
# casual and registered seems to be the breakup by category for total_count column.
df.drop(['instant','dteday','casual','registered'],axis=1,inplace=True)

# %%
# mapping the season column
df.season = df.season.map({1:'spring', 2:'summer', 3:'fall', 4:'winter'})

# mapping the month column
df.month = df.month.map({1:'jan',2:'feb',3:'mar',4:'apr',5:'may',6:'june',7:'july',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'})

# mapping the weekday column
df.weekday = df.weekday.map({0:'sun',1:'mon',2:'tue',3:'wed',4:'thu',5:'fri',6:'sat'})

# mapping the weathersit column
df.weathersit = df.weathersit.map({1:'clear',2:'mist_cloudy',3:'light_rain',4:'heavy_rain'})


df.head()
# Out:
#    season  year month  holiday weekday  workingday   weathersit       temp  \
# 0  spring     0   jan        0     mon           1  mist_cloudy  14.110847
# 1  spring     0   jan        0     tue           1  mist_cloudy  14.902598
# 2  spring     0   jan        0     wed           1        clear   8.050924
# 3  spring     0   jan        0     thu           1        clear   8.200000
# 4  spring     0   jan        0     fri           1        clear   9.305237
#
#       atemp  humidity  windspeed  total_count
# 0  18.18125   80.5833  10.749882          985
# 1  17.68695   69.6087  16.652113          801
# 2   9.47025   43.7273  16.636703         1349
# 3  10.60610   59.0435  10.739832         1562
# 4  11.46350   43.6957  12.522300         1600

# %%
# Analysing the categorical columns to see how predictor variable stands against the target variable
plt.figure(figsize=(20, 12))
plt.subplot(2,4,1)
sns.boxplot(x = 'season', y = 'total_count', data = df)
plt.subplot(2,4,2)
sns.boxplot(x = 'month', y = 'total_count', data = df)
plt.subplot(2,4,3)
sns.boxplot(x = 'weekday', y = 'total_count', data = df)
plt.subplot(2,4,4)
sns.boxplot(x = 'weathersit', y = 'total_count', data = df)
plt.subplot(2,4,5)
sns.boxplot(x = 'holiday', y = 'total_count', data = df)
plt.subplot(2,4,6)
sns.boxplot(x = 'workingday', y = 'total_count', data = df)
plt.subplot(2,4,7)
sns.boxplot(x = 'year', y = 'total_count', data = df)
plt.show()

# %%
# function to create barplot related to categorical columns
def plot_cat_columns(column):
    sns.barplot(column,'total_count',data=df, hue='year',palette='Set1')
    plt.legend(labels=['2018', '2019'])
    plt.show()

# %%
# Bar-plot visualization for categorical columns
Columns=['season','month','weekday','weathersit','holiday','workingday','year']

for col in Columns:
    print("Plotting for "+col)
    plot_cat_columns(col)
# Out:
# Plotting for season
# Plotting for month
# Plotting for weekday
# Plotting for weathersit
# Plotting for holiday
# Plotting for workingday
# Plotting for year

# %% [markdown]
# ##### Below are the points can be drawn from the dataset after analysing the Categorical Columns using Box Plot & Bar Plot
# 1. Fall season seems to have attracted more booking.
# 2. Most of the bookings has been done during the month of may, june, july, aug, sep and oct.
# 3. Clear weather attracted more booking which seems obvious.
# 4. Thu, Fir, Sat and Sun have more number of bookings as compared to the start of the week.
# 5. When its not holiday, booking looks to be less in number which seems reasonable as on holidays.
# 6. Booking seemed to be almost equal either on working day or non-working day.
# 7. In every Category 2019 attracted more number of booking from the previous year 2018, which is a good sign in terms of business.

# %%
# Analysing the numerical columns
sns.pairplot(data=df,vars=['temp','atemp','humidity','windspeed','total_count'])
plt.show()

# %%
# Checking the correlation between the numerical variables
plt.figure(figsize = (6,6))
matrix = np.triu(df[['temp','atemp','humidity','windspeed','total_count']].corr())
sns.heatmap(df[['temp','atemp','humidity','windspeed','total_count']].corr(), annot = True, cmap="GnBu", mask=matrix)
plt.title("Correlation between Numerical Variables")
plt.show()

# %% [markdown]
# ##### After Analysing Numerical Columns using scater plot and Heat map plot, below point can be drawn
# 1. There is linear relationship between temp and atemp. Both of the parameters cannot be used in the model due to multicolinearity. We will decide which parameters to keep based on VIF and p-value w.r.t other variables
# 2. W.r.t total_count vs humidity and total_count vs windspeed seems to be having -ve linear relationship in between them.

# %% [markdown]
# ### Step 2: Data Preparation

# %%
# Dummy variable creation for month, weekday, weathersit, season,year variables
months_df=pd.get_dummies(df.month,drop_first=True)
weekdays_df=pd.get_dummies(df.weekday,drop_first=True)
weathersit_df=pd.get_dummies(df.weathersit,drop_first=True)
seasons_df=pd.get_dummies(df.season,drop_first=True)


# Merging  the dataframe, with the dummy variable dataset. 
df_new = pd.concat([df,months_df,weekdays_df,weathersit_df,seasons_df],axis=1)
df_new.head()
# Out:
#    season  year month  holiday weekday  workingday   weathersit       temp  \
# 0  spring     0   jan        0     mon           1  mist_cloudy  14.110847
# 1  spring     0   jan        0     tue           1  mist_cloudy  14.902598
# 2  spring     0   jan        0     wed           1        clear   8.050924
# 3  spring     0   jan        0     thu           1        clear   8.200000
# 4  spring     0   jan        0     fri           1        clear   9.305237
#
#       atemp  humidity  ...  sat  sun  thu  tue  wed  light_rain  mist_cloudy  \
# 0  18.18125   80.5833  ...    0    0    0    0    0           0            1
# 1  17.68695   69.6087  ...    0    0    0    1    0           0            1
# 2   9.47025   43.7273  ...    0    0    0    0    1           0            0
# 3  10.60610   59.0435  ...    0    0    1    0    0           0            0
# 4  11.46350   43.6957  ...    0    0    0    0    0           0            0
#
#    spring  summer  winter
# ...

# %%
# dropping unnecessary columns as we have already created dummy variable out of it.
df_new.drop(['season','month','weekday','weathersit'], axis = 1, inplace = True)
df_new.head()
# Out:
#    year  holiday  workingday       temp     atemp  humidity  windspeed  \
# 0     0        0           1  14.110847  18.18125   80.5833  10.749882
# 1     0        0           1  14.902598  17.68695   69.6087  16.652113
# 2     0        0           1   8.050924   9.47025   43.7273  16.636703
# 3     0        0           1   8.200000  10.60610   59.0435  10.739832
# 4     0        0           1   9.305237  11.46350   43.6957  12.522300
#
#    total_count  aug  dec  ...  sat  sun  thu  tue  wed  light_rain  \
# 0          985    0    0  ...    0    0    0    0    0           0
# 1          801    0    0  ...    0    0    0    1    0           0
# 2         1349    0    0  ...    0    0    0    0    1           0
# 3         1562    0    0  ...    0    0    1    0    0           0
# 4         1600    0    0  ...    0    0    0    0    0           0
#
#    mist_cloudy  spring  summer  winter
# 0            1       1       0       0
# 1            1       1       0       0
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         730 non-null    int64
#  1   holiday      730 non-null    int64
#  2   workingday   730 non-null    int64
#  3   temp         730 non-null    float64
#  4   atemp        730 non-null    float64
#  5   humidity     730 non-null    float64
#  6   windspeed    730 non-null    float64
#  7   total_count  730 non-null    int64
#  8   aug          730 non-null    uint8
#  9   dec          730 non-null    uint8
#  10  feb          730 non-null    uint8
#  11  jan          730 non-null    uint8
#  12  july         730 non-null    uint8
#  13  june         730 non-null    uint8
#  14  mar          730 non-null    uint8
#  15  may          730 non-null    uint8
#  16  nov          730 non-null    uint8
#  17  oct          730 non-null    uint8
# ...

# %% [markdown]
# ### Step 3: Splitting the Data into Train and Test Data Sets

# %%
np.random.seed(0)
df_train, df_test = train_test_split(df_new, train_size = 0.7, random_state = 100)

print(df_train.shape)
print(df_test.shape)
# Out:
# (510, 30)
# (220, 30)

# %%
# Using MinMaxScaler to Rescaling the features
scaler = MinMaxScaler()
df_train.head()
# Out:
#      year  holiday  workingday       temp    atemp  humidity  windspeed  \
# 576     1        0           1  29.246653  33.1448   70.4167  11.083475
# 426     1        0           0  16.980847  20.6746   62.1250  10.792293
# 728     1        0           1  10.489153  11.5850   48.3333  23.500518
# 482     1        0           0  15.443347  18.8752   48.9583   8.708325
# 111     0        0           0  13.803347  16.0977   72.9583  14.707907
#
#      total_count  aug  dec  ...  sat  sun  thu  tue  wed  light_rain  \
# 576         7216    0    0  ...    0    0    0    0    1           0
# 426         4066    0    0  ...    0    1    0    0    0           0
# 728         1796    0    1  ...    0    0    0    0    0           0
# 482         4220    0    0  ...    0    1    0    0    0           0
# 111         1683    0    0  ...    0    1    0    0    0           0
#
#      mist_cloudy  spring  summer  winter
# 576            0       0       0       0
# ...

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
num_vars = ['temp','atemp','humidity','windspeed','total_count']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

df_train.head()
# Out:
#      year  holiday  workingday      temp     atemp  humidity  windspeed  \
# 576     1        0           1  0.815169  0.766351  0.725633   0.264686
# 426     1        0           0  0.442393  0.438975  0.640189   0.255342
# 728     1        0           1  0.245101  0.200348  0.498067   0.663106
# 482     1        0           0  0.395666  0.391735  0.504508   0.188475
# 111     0        0           0  0.345824  0.318819  0.751824   0.380981
#
#      total_count  aug  dec  ...  sat  sun  thu  tue  wed  light_rain  \
# 576     0.827658    0    0  ...    0    0    0    0    1           0
# 426     0.465255    0    0  ...    0    1    0    0    0           0
# 728     0.204096    0    1  ...    0    0    0    0    0           0
# 482     0.482973    0    0  ...    0    1    0    0    0           0
# 111     0.191095    0    0  ...    0    1    0    0    0           0
#
#      mist_cloudy  spring  summer  winter
# 576            0       0       0       0
# ...

# %%
# describing the dataset
df_train.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.025490    0.711765    0.537440    0.513156    0.650480
# std      0.500429    0.157763    0.453386    0.225858    0.212410    0.145846
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.339853    0.332086    0.538643
# 50%      1.000000    0.000000    1.000000    0.542596    0.529718    0.653714
# 75%      1.000000    0.000000    1.000000    0.735215    0.688457    0.754830
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed  total_count         aug         dec  ...         sat  \
# count  510.000000   510.000000  510.000000  510.000000  ...  510.000000
# mean     0.320883     0.513499    0.096078    0.084314  ...    0.129412
# ...

# %%
# check the correlation coefficients to see which variables are highly correlated
plt.figure(figsize = (30,30))
matrix = np.triu(df_train.corr())
sns.heatmap(df_train.corr(), annot = True, cmap="RdYlGn", mask=matrix)
plt.show()

# %% [markdown]
# ##### variables are highly correlated
# 1. Total_count seems to have correlation with year 2019 and temp variable.
# 2. mist_cloudy and humidity show correlation.
# 3. Spring season with Jan and Feb month, Summer season with May month and Winter season with Oct and Nov month show good correlation.

# %%
# Visualizing one of the correlation to see the trends via Scatter plot.
plt.figure(figsize=[4,4])
plt.scatter(df_train.temp, df_train.total_count)
plt.show()

# %% [markdown]
# Visualization confirms the positive correlation between temp and total_count.

# %% [markdown]
# ### Step-4 Building the Linear Model

# %%
y_train = df_train.pop('total_count')
X_train = df_train

# Recursive feature elimination 
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, 15)
rfe = rfe.fit(X_train, y_train)

#List of variables selected in top 15 list
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('year', True, 1),
#  ('holiday', True, 1),
#  ('workingday', False, 4),
#  ('temp', True, 1),
#  ('atemp', False, 3),
#  ('humidity', True, 1),
#  ('windspeed', True, 1),
#  ('aug', False, 10),
#  ('dec', True, 1),
#  ('feb', False, 2),
#  ('jan', True, 1),
#  ('july', True, 1),
#  ('june', False, 12),
#  ('mar', False, 15),
#  ('may', False, 9),
#  ('nov', True, 1),
#  ('oct', False, 13),
#  ('sep', True, 1),
#  ('mon', False, 8),
#  ('sat', False, 5),
#  ('sun', False, 6),
#  ('thu', False, 14),
#  ('tue', False, 7),
#  ('wed', False, 11),
#  ('light_rain', True, 1),
#  ('mist_cloudy', True, 1),
#  ('spring', True, 1),
#  ('summer', True, 1),
#  ('winter', True, 1)]

# %%
# selecting the selected variable via RFE in col list
col = X_train.columns[rfe.support_]
print(col)
# Out:
# Index(['year', 'holiday', 'temp', 'humidity', 'windspeed', 'dec', 'jan',
#        'july', 'nov', 'sep', 'light_rain', 'mist_cloudy', 'spring', 'summer',
#        'winter'],
#       dtype='object')

# %%
# checking which columns has been rejected
X_train.columns[~rfe.support_]
# Out:
# Index(['workingday', 'atemp', 'aug', 'feb', 'june', 'mar', 'may', 'oct', 'mon',
#        'sat', 'sun', 'thu', 'tue', 'wed'],
#       dtype='object')

# %%
# Generic function to calculate VIF of variables
def calculateVIF(df):
    vif = pd.DataFrame()
    vif['Features'] = df.columns
    vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return vif

# %%
# dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# calculate VIF
calculateVIF(X_train_rfe)
# Out:
#        Features    VIF
# 3      humidity  30.89
# 2          temp  17.79
# 4     windspeed   4.72
# 12       spring   4.37
# 14       winter   4.06
# 13       summer   2.82
# 11  mist_cloudy   2.32
# 0          year   2.09
# 8           nov   1.85
# 6           jan   1.75
# 7          july   1.59
# 5           dec   1.56
# 9           sep   1.41
# 10   light_rain   1.28
# 1       holiday   1.06

# %%
# Building 1st linear regression model
X_train_lm_1 = sm.add_constant(X_train_rfe)
lr_1 = sm.OLS(y_train,X_train_lm_1).fit()
print(lr_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_count   R-squared:                       0.845
# Model:                            OLS   Adj. R-squared:                  0.840
# Method:                 Least Squares   F-statistic:                     179.4
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):          8.15e-189
# Time:                        21:30:16   Log-Likelihood:                 514.19
# No. Observations:                 510   AIC:                            -996.4
# Df Residuals:                     494   BIC:                            -928.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.3197      0.036      8.859      0.000       0.249       0.391
# ...

# %%
# As humidity shows high VIF values hence we can drop it
X_train_new = X_train_rfe.drop(['humidity'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#        Features   VIF
# 2          temp  5.17
# 3     windspeed  4.67
# 13       winter  2.95
# 11       spring  2.89
# 12       summer  2.24
# 0          year  2.07
# 7           nov  1.81
# 5           jan  1.66
# 6          july  1.59
# 10  mist_cloudy  1.57
# 4           dec  1.47
# 8           sep  1.35
# 9    light_rain  1.09
# 1       holiday  1.06

# %%
# Building 2nd linear regression model
X_train_lm_2 = sm.add_constant(X_train_new)
lr_2 = sm.OLS(y_train,X_train_lm_2).fit()
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_count   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     184.5
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):          4.75e-186
# Time:                        21:30:16   Log-Likelihood:                 504.85
# No. Observations:                 510   AIC:                            -979.7
# Df Residuals:                     495   BIC:                            -916.2
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.2450      0.032      7.618      0.000       0.182       0.308
# ...

# %%
# We can drop nov variable as it has high p-value
X_train_new = X_train_new.drop(['nov'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#        Features   VIF
# 2          temp  5.14
# 3     windspeed  4.62
# 10       spring  2.89
# 11       summer  2.24
# 0          year  2.07
# 12       winter  2.05
# 5           jan  1.65
# 6          july  1.59
# 9   mist_cloudy  1.57
# 7           sep  1.34
# 4           dec  1.29
# 8    light_rain  1.08
# 1       holiday  1.04

# %%
# Building 3rd linear regression model
X_train_lm_3 = sm.add_constant(X_train_new)
lr_3 = sm.OLS(y_train,X_train_lm_3).fit()
print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_count   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     197.0
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):          2.74e-186
# Time:                        21:30:16   Log-Likelihood:                 502.67
# No. Observations:                 510   AIC:                            -977.3
# Df Residuals:                     496   BIC:                            -918.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.2283      0.031      7.310      0.000       0.167       0.290
# ...

# %%
# We can drop dec variable as it has high p-value
X_train_new = X_train_new.drop(['dec'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#        Features   VIF
# 2          temp  5.13
# 3     windspeed  4.62
# 9        spring  2.75
# 10       summer  2.24
# 0          year  2.07
# 11       winter  1.78
# 4           jan  1.61
# 5          july  1.59
# 8   mist_cloudy  1.56
# 6           sep  1.34
# 7    light_rain  1.08
# 1       holiday  1.04

# %%
# Building 4th linear regression model
X_train_lm_4 = sm.add_constant(X_train_new)
lr_4 = sm.OLS(y_train,X_train_lm_4).fit()
print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_count   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     212.3
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):          8.14e-187
# Time:                        21:30:16   Log-Likelihood:                 501.13
# No. Observations:                 510   AIC:                            -976.3
# Df Residuals:                     497   BIC:                            -921.2
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.2154      0.030      7.088      0.000       0.156       0.275
# ...

# %%
# We can drop jan variable as it has high p-value
X_train_new = X_train_new.drop(['jan'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#        Features   VIF
# 2          temp  5.09
# 3     windspeed  4.60
# 9        summer  2.23
# 8        spring  2.08
# 0          year  2.07
# 10       winter  1.78
# 4          july  1.58
# 7   mist_cloudy  1.55
# 5           sep  1.34
# 6    light_rain  1.08
# 1       holiday  1.04

# %%
# Building 5th linear regression model
X_train_lm_5 = sm.add_constant(X_train_new)
lr_5 = sm.OLS(y_train,X_train_lm_5).fit()
print(lr_5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_count   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     229.6
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):          5.06e-187
# Time:                        21:30:16   Log-Likelihood:                 498.80
# No. Observations:                 510   AIC:                            -973.6
# Df Residuals:                     498   BIC:                            -922.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1994      0.030      6.746      0.000       0.141       0.258
# ...

# %%
# We can drop july variable as it has high p-value
X_train_new = X_train_new.drop(['july'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#       Features   VIF
# 3    windspeed  4.60
# 2         temp  3.84
# 0         year  2.07
# 7       spring  1.99
# 8       summer  1.90
# 9       winter  1.63
# 6  mist_cloudy  1.55
# 4          sep  1.23
# 5   light_rain  1.08
# 1      holiday  1.04

# %% [markdown]
# VIF value looks to be good now as it came below 5

# %%
# Building 6th linear regression model
X_train_lm_6 = sm.add_constant(X_train_new)
lr_6 = sm.OLS(y_train,X_train_lm_6).fit()
print(lr_6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_count   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     248.4
# Date:                Tue, 08 Nov 2022   Prob (F-statistic):          1.47e-186
# Time:                        21:30:16   Log-Likelihood:                 494.84
# No. Observations:                 510   AIC:                            -967.7
# Df Residuals:                     499   BIC:                            -921.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1909      0.030      6.447      0.000       0.133       0.249
# ...

# %% [markdown]
# 1. We can cosider the above model i.e lr_6, as it looks to have very low multicolinearity between the predictors and the p-values for all the predictors.
# 2. F-Statistics value of 248.4 (which is greater than 1) and the p-value of 1.47e-186 i.e almost equals to zero, states that the overall model is significant.

# %%
# Checking the parameters and their coefficient values
lr_6.params
# Out:
# const          0.190855
# year           0.234132
# holiday       -0.096316
# temp           0.477737
# windspeed     -0.148098
# sep            0.090998
# light_rain    -0.285031
# mist_cloudy   -0.078741
# spring        -0.055406
# summer         0.062076
# winter         0.094476
# dtype: float64

# %% [markdown]
# ### Step 5: Residual Analysis of the train data and validation

# %%
X_train_lm_6
# Out:
#      const  year  holiday      temp  windspeed  sep  light_rain  mist_cloudy  \
# 576    1.0     1        0  0.815169   0.264686    0           0            0
# 426    1.0     1        0  0.442393   0.255342    0           0            1
# 728    1.0     1        0  0.245101   0.663106    0           0            0
# 482    1.0     1        0  0.395666   0.188475    0           0            1
# 111    1.0     0        0  0.345824   0.380981    0           0            1
# ..     ...   ...      ...       ...        ...  ...         ...          ...
# 578    1.0     1        0  0.863973   0.187140    0           0            0
# 53     1.0     0        0  0.202618   0.111379    0           0            0
# 350    1.0     0        0  0.248216   0.431816    0           0            1
# 79     1.0     0        0  0.462664   0.529881    0           0            1
# 520    1.0     1        0  0.600225   0.359599    0           0            1
#
#      spring  summer  winter
# ...

# %%
y_train_pred = lr_6.predict(X_train_lm_6)

# %%
# Normality of error terms
  # Plot the histogram of the error terms

fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Error Terms', fontsize = 20) 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
# Multi Colinearity
calculateVIF(X_train_new)
# Out:
#       Features   VIF
# 3    windspeed  4.60
# 2         temp  3.84
# 0         year  2.07
# 7       spring  1.99
# 8       summer  1.90
# 9       winter  1.63
# 6  mist_cloudy  1.55
# 4          sep  1.23
# 5   light_rain  1.08
# 1      holiday  1.04

# %%
plt.figure(figsize=(15,8))
matrix = np.triu(X_train_new.corr())
sns.heatmap(X_train_new.corr(),annot = True, cmap="RdYlGn",mask=matrix)
plt.show()

# %% [markdown]
# VIF values are less than 5 which is good and also there is no multicolinearity as seen from the heatmap.

# %%
# Linearity Check
  # Linear relationship validation using CCPR plot (Component and component plus residual plot)
sm.graphics.plot_ccpr(lr_6, 'temp')
plt.show()

sm.graphics.plot_ccpr(lr_6, 'sep')
plt.show()

sm.graphics.plot_ccpr(lr_6, 'windspeed')
plt.show()

# %% [markdown]
# Linearity can be observed from above visualizations.

# %%
# Homoscedasticity
y_train_pred = lr_6.predict(X_train_lm_6)
residual = y_train - y_train_pred
sns.scatterplot(y_train,residual)
plt.plot(y_train,(y_train - y_train), '-r')
plt.xlabel('Count')
plt.ylabel('Residual')
plt.show()

# %% [markdown]
# No visible pattern observed from above plot for residuals. All Data point lies close to 0 line.

# %% [markdown]
# ### Step 6: Making Predictions Using the Final Model

# %%
# Applying scaling on the test dataset
num_vars = ['temp', 'atemp', 'humidity', 'windspeed','total_count']
df_test[num_vars] = scaler.transform(df_test[num_vars])
df_test.head()
# Out:
#      year  holiday  workingday      temp     atemp  humidity  windspeed  \
# 184     0        1           0  0.831783  0.769660  0.657364   0.084219
# 535     1        0           1  0.901354  0.842587  0.610133   0.153728
# 299     0        0           0  0.511964  0.496145  0.837699   0.334206
# 221     0        0           1  0.881625  0.795343  0.437098   0.339570
# 152     0        0           0  0.817246  0.741471  0.314298   0.537414
#
#      total_count  aug  dec  ...  sat  sun  thu  tue  wed  light_rain  \
# 184     0.692706    0    0  ...    0    0    0    0    1           0
# 535     0.712034    0    0  ...    0    0    1    0    0           0
# 299     0.303382    0    0  ...    1    0    0    0    0           0
# 221     0.547400    1    0  ...    0    0    0    0    0           0
# 152     0.569029    0    0  ...    1    0    0    0    0           0
#
#      mist_cloudy  spring  summer  winter
# 184            1       0       0       0
# ...

# %%
df_test.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  220.000000  220.000000  220.000000  220.000000  220.000000  220.000000
# mean     0.481818    0.036364    0.640909    0.558718    0.532847    0.638221
# std      0.500809    0.187620    0.480828    0.233187    0.217401    0.148694
# min      0.000000    0.000000    0.000000    0.046591    0.025950    0.261915
# 25%      0.000000    0.000000    0.000000    0.355429    0.344870    0.529197
# 50%      0.000000    0.000000    1.000000    0.558172    0.544652    0.625590
# 75%      1.000000    0.000000    1.000000    0.755981    0.713308    0.743798
# max      1.000000    1.000000    1.000000    0.984424    0.980934    1.002146
#
#         windspeed  total_count         aug         dec  ...         sat  \
# count  220.000000   220.000000  220.000000  220.000000  ...  220.000000
# mean     0.313293     0.522154    0.059091    0.086364  ...    0.172727
# ...

# %%
y_test = df_test.pop('total_count')
X_test = df_test
col1 = X_train_new.columns

X_test = X_test[col1]

# Adding constant variable to test dataframe
X_test_lm_6 = sm.add_constant(X_test)
y_pred = lr_6.predict(X_test_lm_6)
r2 = r2_score(y_test, y_pred)
print(round(r2,4))
# Out:
# 0.8038

# %% [markdown]
# ### Step 7: Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread
fig = plt.figure()
plt.scatter(y_test, y_pred)
fig.suptitle('Y_TEST Vs Y_PRED', fontsize = 20) 
plt.xlabel('y_test', fontsize = 18)
plt.ylabel('y_pred', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
round(lr_6.params,4)
# Out:
# const          0.1909
# year           0.2341
# holiday       -0.0963
# temp           0.4777
# windspeed     -0.1481
# sep            0.0910
# light_rain    -0.2850
# mist_cloudy   -0.0787
# spring        -0.0554
# summer         0.0621
# winter         0.0945
# dtype: float64

# %% [markdown]
# ##### Now we Can see the Linear Equation of best fitted line below
# total_count= 0.1909-0.0963* holiday +0.4777* temp-0.1481* windspeed+0.0910* sep-0.2850* light_rain-0.0787* mist_cloudy-0.0554* spring+0.0621* summer+0.0945* winter+0.2341* year

# %%
# Calculating Adjusted-R^2 value for the test dataset
adjusted_r2 = round(1-(1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1),4)
print(adjusted_r2)
# Out:
# 0.7944

# %%
# Visualizing the fit on the test data
# plotting a Regression plot
plt.figure()
sns.regplot(x=y_test, y=y_pred, ci=68, fit_reg=True,scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title('Y_TEST Vs Y_PRED', fontsize=20)
plt.xlabel('y_test', fontsize=18)
plt.ylabel('y_pred', fontsize=16)
plt.show()

# %% [markdown]
# #### Comparision between Training and Testing dataset:
# - Train dataset R^2          : 0.833
# - Test dataset R^2           : 0.8038
# - Train dataset Adjusted R^2 : 0.829
# - Test dataset Adjusted R^2  : 0.7944
#
# Demand of bikes depend on year, holiday, temp, windspeed, Month (sep), Weather(light_rain, mist_cloudy) and Season (spring, summer, winter).
